# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
df1 = pd.read_csv("nytimes_economy_1.csv")

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
# Choose the column containing the text
text_col = 'abstract'

# Drop rows with missing text
df1 = df1.dropna(subset=[text_col, 'pub_date'])

# Compute sentiment
df1 = df1.copy()
df1['sentiment'] = df1[text_col].apply(
    lambda x: analyzer.polarity_scores(x)['compound']
)

# %%
df1['pub_date'] = pd.to_datetime(df1['pub_date'])
df1['date'] = df1['pub_date'].dt.date

# %%
daily_sentiment = df1.groupby('date')['sentiment'].mean().reset_index()

# %%
import matplotlib.pyplot as plt

# Assume daily_sentiment has 'date' and 'sentiment' columns
plt.figure(figsize=(12,6))
plt.plot(daily_sentiment['date'], daily_sentiment['sentiment'], marker='o', linestyle='-')
plt.title('Daily Average Sentiment of NYT Articles')
plt.xlabel('Date')
plt.ylabel('Average Sentiment (VADER Compound Score)')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
daily_sentiment['sentiment_7d'] = daily_sentiment['sentiment'].rolling(window=7, min_periods=1).mean()

# Plot original sentiment and rolling average
plt.figure(figsize=(12,6))
plt.plot(daily_sentiment['date'], daily_sentiment['sentiment'], marker='o', linestyle='-', alpha=0.5, label='Daily Sentiment')
plt.plot(daily_sentiment['date'], daily_sentiment['sentiment_7d'], color='red', linewidth=2, label='7-Day Rolling Average')
plt.title('Daily Sentiment with 7-Day Rolling Average')
plt.xlabel('Date')
plt.ylabel('Sentiment (VADER Compound Score)')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
daily_sentiment['sentiment_30d'] = daily_sentiment['sentiment'].rolling(window=30, min_periods=1).mean()

# Plot original sentiment and rolling average
plt.figure(figsize=(12,6))
plt.plot(daily_sentiment['date'], daily_sentiment['sentiment'], marker='o', linestyle='-', alpha=0.3, label='Daily Sentiment')
plt.plot(daily_sentiment['date'], daily_sentiment['sentiment_30d'], color='red', linewidth=2, label='30-Day Rolling Average')
plt.title('Daily Sentiment with 30-Day Rolling Average')
plt.xlabel('Date')
plt.ylabel('Sentiment (VADER Compound Score)')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig("results/sentiment", bbox_inches="tight")
plt.show()
