# %%
import requests
import pandas as pd

# %%
API_KEY = "qrZUHabbbGHJWU95326BITrpe1ZX6SbC79MvFmbIKuEICM9l"

def get_nyt_articles(query, begin_date, end_date, page=0):
    url = "https://api.nytimes.com/svc/search/v2/articlesearch.json"
    
    params = {
        "q": query,
        "begin_date": begin_date,  # format YYYYMMDD
        "end_date": end_date,
        "page": page,
        "api-key": API_KEY
    }
    
    response = requests.get(url, params=params)
    
    # 🔎 Debugging output
    print("Status Code:", response.status_code)
    print("Response JSON snippet:", response.json())
    
    data = response.json()
    
    if response.status_code != 200 or "response" not in data:
        print("Error or unexpected response")
        return pd.DataFrame()
    
    articles = []
    for doc in data["response"]["docs"]:
        articles.append({
            "headline": doc["headline"]["main"],
            "pub_date": doc["pub_date"],
            "snippet": doc.get("snippet", ""),
            "web_url": doc["web_url"]
        })
    
    return pd.DataFrame(articles)

# %%
all_articles = pd.DataFrame()

for page in range(10):
    df = get_nyt_articles(
        query="economy",
        begin_date="20060101",
        end_date="20060220",
        page=page
    )
    all_articles = pd.concat([all_articles, df], ignore_index=True)

all_articles.head()
# Out:
# Status Code: 200
# Response JSON snippet: {'status': 'OK', 'copyright': 'Copyright (c) 2026 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'abstract': 'Alan Greenspan left his successor both a wide berth to set his own policy and some major uncertainties about the future.', 'byline': {'original': 'By EDMUND L. ANDREWS'}, 'document_type': 'article', 'headline': {'main': 'Exit Greenspan, Amid Questions on Economy', 'kicker': '', 'print_headline': ''}, '_id': 'nyt://article/4de832f3-1181-5aee-adfe-5e3fb5337e89', 'keywords': [], 'multimedia': {'caption': '', 'credit': '', 'default': {'url': '', 'height': 0, 'width': 0}, 'thumbnail': {'url': '', 'height': 0, 'width': 0}}, 'news_desk': 'Business', 'print_page': '', 'print_section': '', 'pub_date': '2006-02-01T05:00:00Z', 'section_name': 'Business', 'snippet': 'Alan Greenspan left his successor both a wide berth to set his own policy and some major uncertainties about the future.', 'source': 'The New York Times', 'subsection_name': '', 'type_of_material': 'News', 'uri': 'nyt://article/4de832f3-1181-5aee-adfe-5e3fb5337e89', 'web_url': 'https://www.nytimes.com/2006/02/01/business/01fed.html', 'word_count': 0}, {'abstract': "The Chinese statistics, showing a national economic output of $2.26 trillion, sent China soaring past France, Britain and Italy to become the world's fourth-largest economy.", 'byline': {'original': 'By Keith Bradsher'}, 'document_type': 'article', 'headline': {'main': 'Chinese Economy Becomes 4th Largest in the World', 'kicker': '', 'print_headline': 'Chinese Economy Becomes 4th Largest in the World'}, '_id': 'nyt://article/2905419b-8fde-5d18-ad0e-3faf04a2670d', 'keywords': [{'name': 'Location', 'value': 'China', 'rank': 1}, {'name': 'Subject', 'value': 'Economic Conditions and Trends', 'rank': 2}], 'multimedia': {'caption': '', 'credit': '', 'default': {'url': '', 'height': 0, 'width': 0}, 'thumbnail': {'url': '', 'height': 0, 'width': 0}}, 'news_desk': 'Business / World Business', 'print_page': '', 'print_section': '', 'pub_date': '2006-01-25T05:00:00Z', 'section_name': 'Business', 'snippet': "The Chinese statistics, showing a national economic output of $2.26 trillion, sent China soaring past France, Britain and Italy to become the world's fourth-largest economy.", 'source': 'The New York Times', 'subsection_name': 'International Business', 'type_of_material': 'News', 'uri': 'nyt://article/2905419b-8fde-5d18-ad0e-3faf04a2670d', 'web_url': 'https://www.nytimes.com/2006/01/25/business/worldbusiness/chinese-economy-becomes-4th-largest-in-the-world.html', 'word_count': 763}, {'abstract': 'The United States generated about 200,000 new jobs a month in the last part of 2005, a healthy pace that President Bush immediately used on Friday as part of a broader campaign to promote his economic record and agenda of tax cuts, tighter limits on government spending and more trade.     The nation added 108,000 jobs in December as the unemployment rate edged down to 4.9 percent, the Labor Department said Friday.  ', 'byline': {'original': 'By Edmund L. Andrews and Richard W. Stevenson'}, 'document_type': 'article', 'headline': {'main': 'Bush Cites 2 Million New Jobs in 2005 and Healthy Economy', 'kicker': '', 'print_headline': 'Bush Cites 2 Million New Jobs in 2005 and Healthy Economy'}, '_id': 'nyt://article/313ed1c5-243e-55ef-b28b-73dc8a670bcf', 'keywords': [{'name': 'Subject', 'value': 'United States Economy', 'rank': 1}, {'name': 'Subject', 'value': 'Economic Conditions and Trends', 'rank': 2}], 'multimedia': {'caption': '', 'credit': '', 'default': {'url': '', 'height': 0, 'width': 0}, 'thumbnail': {'url': '', 'height': 0, 'width': 0}}, 'news_desk': 'Business/Financial Desk', 'print_page': '00001', 'print_section': 'C', 'pub_date': '2006-01-07T05:00:00Z', 'section_name': 'Business', 'snippet': 'The United States generated about 200,000 new jobs a month in the last part of 2005, a healthy pace that President Bush immediately used on Friday as part of a broader campaig ...
# Status Code: 200
# Response JSON snippet: {'status': 'OK', 'copyright': 'Copyright (c) 2026 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'abstract': "Japanese economic growth surged 5.5 percent in fourth quarter as country's economic revival picked up amid rising consumer spending and strong exports; marks fourth consecutive quarter of growth; Japan's economic growth comes at time when growth in United States and Europe appears to be slowing; growth figures beat estimates of 5 percent; consumer spending rose 0.8 percent (M)", 'byline': {'original': 'By Martin Fackler'}, 'document_type': 'article', 'headline': {'main': "Japan's Economy Surged 5.5% in 4th Quarter", 'kicker': 'INTERNATIONAL BUSINESS', 'print_headline': "INTERNATIONAL BUSINESS; Japan's Economy Surged 5.5% in 4th Quarter"}, '_id': 'nyt://article/15ff35b4-104c-5a42-a1e3-599c38fb6bb4', 'keywords': [{'name': 'Location', 'value': 'Japan', 'rank': 1}, {'name': 'Location', 'value': 'Europe', 'rank': 2}, {'name': 'Organization', 'value': 'European Union', 'rank': 3}, {'name': 'Subject', 'value': 'International Trade and World Market', 'rank': 4}, {'name': 'Subject', 'value': 'United States Economy', 'rank': 5}, {'name': 'Subject', 'value': 'Wages and Salaries', 'rank': 6}, {'name': 'Subject', 'value': 'Economic Conditions and Trends', 'rank': 7}, {'name': 'Subject', 'value': 'Consumer Behavior', 'rank': 8}], 'multimedia': {'caption': '', 'credit': '', 'default': {'url': '', 'height': 0, 'width': 0}, 'thumbnail': {'url': '', 'height': 0, 'width': 0}}, 'news_desk': 'Business/Financial Desk', 'print_page': '00005', 'print_section': 'C', 'pub_date': '2006-02-17T05:00:00Z', 'section_name': 'Business', 'snippet': "Japanese economic growth surged 5.5 percent in fourth quarter as country's economic revival picked up amid rising consumer spending and strong exports; marks fourth consecutive quarter of growth; Japan's economic growth comes at time when growth in United States and Europe appears to be slowing; growth figures beat estimates of 5 percent; consumer spending rose 0.8 percent (M)", 'source': 'The New York Times', 'subsection_name': '', 'type_of_material': 'News', 'uri': 'nyt://article/15ff35b4-104c-5a42-a1e3-599c38fb6bb4', 'web_url': 'https://www.nytimes.com/2006/02/17/business/japans-economy-surged-55-in-4th-quarter.html', 'word_count': 591}, {'abstract': 'Americans spent freely in January, providing reassurance that the economy is beginning the new year with fresh strength.', 'byline': {'original': 'By Vikas Bajaj  and Michael Barbaro'}, 'document_type': 'article', 'headline': {'main': 'Retail Sales Climb, in Sign of Fresh Strength in Economy', 'kicker': '', 'print_headline': 'Retail Sales Climb, in Sign of Fresh Strength in Economy'}, '_id': 'nyt://article/727e3fc0-070b-5142-a424-b5edb29d132a', 'keywords': [{'name': 'Organization', 'value': 'Commerce Department', 'rank': 1}, {'name': 'Subject', 'value': 'SALES', 'rank': 2}, {'name': 'Subject', 'value': 'RETAIL STORES AND TRADE', 'rank': 3}, {'name': 'Subject', 'value': 'United States Economy', 'rank': 4}], 'multimedia': {'caption': '', 'credit': '', 'default': {'url': '', 'height': 0, 'width': 0}, 'thumbnail': {'url': '', 'height': 0, 'width': 0}}, 'news_desk': 'Business', 'print_page': '', 'print_section': '', 'pub_date': '2006-02-14T05:00:00Z', 'section_name': 'Business', 'snippet': 'Americans spent freely in January, providing reassurance that the economy is beginning the new year with fresh strength.', 'source': 'The New York Times', 'subsection_name': '', 'type_of_material': 'News', 'uri': 'nyt://article/727e3fc0-070b-5142-a424-b5edb29d132a', 'web_url': 'https://www.nytimes.com/2006/02/14/business/retail-sales-climb-in-sign-of-fresh-strength-in-economy.html', 'word_count': 894}, {'abstract': "IF you believe most statistics, the national economy is doing quite well. Corporate profits are soaring. Consumer spending and business investment have been growing at a healthy clip. In the third quarter of last y ...
# Status Code: 200
# Response JSON snippet: {'status': 'OK', 'copyright': 'Copyright (c) 2026 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'abstract': 'The standards are meant to more accurately depict what consumers can expect from new cars and trucks.', 'byline': {'original': 'By Micheline Maynard'}, 'document_type': 'article', 'headline': {'main': 'E.P.A. Proposes Changes to Fuel Economy Ratings', 'kicker': '', 'print_headline': 'E.P.A. Proposes Changes to Fuel Economy Ratings'}, '_id': 'nyt://article/160a9e4d-5d26-5120-97ab-fc9154b3bb53', 'keywords': [{'name': 'Organization', 'value': 'Environmental Protection Agency', 'rank': 1}, {'name': 'Subject', 'value': 'Automobiles', 'rank': 2}], 'multimedia': {'caption': '', 'credit': '', 'default': {'url': '', 'height': 0, 'width': 0}, 'thumbnail': {'url': '', 'height': 0, 'width': 0}}, 'news_desk': 'Washington', 'print_page': '', 'print_section': '', 'pub_date': '2006-01-10T05:00:00Z', 'section_name': 'U.S.', 'snippet': 'The standards are meant to more accurately depict what consumers can expect from new cars and trucks.', 'source': 'The New York Times', 'subsection_name': 'Politics', 'type_of_material': 'News', 'uri': 'nyt://article/160a9e4d-5d26-5120-97ab-fc9154b3bb53', 'web_url': 'https://www.nytimes.com/2006/01/10/politics/epa-proposes-changes-to-fuel-economy-ratings.html', 'word_count': 467}, {'abstract': 'The Environmental Protection Agency is expected to unveil next week long-awaited changes in the way that it calculates fuel economy ratings for cars and trucks.     The agency is scheduled to announce the action at a news conference on Thursday in Detroit. The announcement falls during the preview days for the North American International Auto Show, which opens to the public next Saturday.  ', 'byline': {'original': 'By Micheline Maynard'}, 'document_type': 'article', 'headline': {'main': 'E.P.A. Set to Reveal Changes in Fuel Economy Calculations', 'kicker': '', 'print_headline': 'E.P.A. Set to Reveal Changes In Fuel Economy Calculations'}, '_id': 'nyt://article/8fa873e9-40e8-57fe-9342-2706fb4460b7', 'keywords': [{'name': 'Organization', 'value': 'Environmental Protection Agency', 'rank': 1}, {'name': 'Subject', 'value': 'Automobiles', 'rank': 2}, {'name': 'Subject', 'value': 'Environment', 'rank': 3}], 'multimedia': {'caption': '', 'credit': '', 'default': {'url': '', 'height': 0, 'width': 0}, 'thumbnail': {'url': '', 'height': 0, 'width': 0}}, 'news_desk': 'Business/Financial Desk', 'print_page': '00013', 'print_section': 'C', 'pub_date': '2006-01-07T05:00:00Z', 'section_name': 'Business', 'snippet': 'The Environmental Protection Agency is expected to unveil next week long-awaited changes in the way that it calculates fuel economy ratings for cars and trucks.     The agency is scheduled to announce the action at a news conference on Thursday in Detroit. The announcement falls during the preview days for the North American International Auto Show, which opens to the public next Saturday.  ', 'source': 'The New York Times', 'subsection_name': '', 'type_of_material': 'News', 'uri': 'nyt://article/8fa873e9-40e8-57fe-9342-2706fb4460b7', 'web_url': 'https://www.nytimes.com/2006/01/07/business/epa-set-to-reveal-changes-in-fuel-economy-calculations.html', 'word_count': 375}, {'abstract': "Brian Lohmann letter holds Matt Bai's essay (Dec 18) on inevitability of Wal-Mart seems to assume that most Americans are willing to give up Social Security employer-financed health care and living wage in order to buy Xboxes and laptops at deep discounts", 'byline': {'original': ''}, 'document_type': 'article', 'headline': {'main': 'New World Economy', 'kicker': '', 'print_headline': 'New World Economy'}, '_id': 'nyt://article/94d6c1b5-256e-5e7c-a8ec-3675e3bcb9ae', 'keywords': [{'name': 'Organization', 'value': 'Wal-Mart Stores Inc', 'rank': 1}, {'name': 'Person', 'value': 'LOHMANN, BRIAN', 'rank': 2}, {'name': 'Person', 'value': 'Bai, Matt', 'rank': 3}, {'name': 'Subject', 'value': 'R ...
# Status Code: 200
# Response JSON snippet: {'status': 'OK', 'copyright': 'Copyright (c) 2026 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'abstract': 'Consumers and the federal government cut back on spending significantly, a government report showed today.', 'byline': {'original': 'By Eduardo Porter  and Vikas Bajaj'}, 'document_type': 'article', 'headline': {'main': 'U.S. Economy Grows at Slowest Pace in Three Years', 'kicker': '', 'print_headline': 'U.S. Economy Grows at Slowest Pace in Three Years'}, '_id': 'nyt://article/67f82e35-7fac-529c-a101-a4f7beb7f13a', 'keywords': [], 'multimedia': {'caption': '', 'credit': '', 'default': {'url': '', 'height': 0, 'width': 0}, 'thumbnail': {'url': '', 'height': 0, 'width': 0}}, 'news_desk': 'Business', 'print_page': '', 'print_section': '', 'pub_date': '2006-01-27T05:00:00Z', 'section_name': 'Business', 'snippet': 'Consumers and the federal government cut back on spending significantly, a government report showed today.', 'source': 'The New York Times', 'subsection_name': '', 'type_of_material': 'News', 'uri': 'nyt://article/67f82e35-7fac-529c-a101-a4f7beb7f13a', 'web_url': 'https://www.nytimes.com/2006/01/27/business/us-economy-grows-at-slowest-pace-in-three-years.html', 'word_count': 1087}, {'abstract': "Vietnam's economy expanded last year at the fastest pace in almost a decade, led by gains in construction, tourism and telecommunications. Gross domestic product increased 8.4 percent in 2005, according to preliminary figures released by the General Statistics Office in Hanoi. The figure is up from a 7.8 percent expansion in 2004, and it is the fastest growth since 1996, the statistics office said. Vietnam, which has cut poverty in half since 1993, wants to move out of the ranks of the world's lower-income nations by 2010. The government aims at achieving the target by spurring economic growth to exceed the 7 percent that it averaged in the five years from 2000 to 2004, even as inflation exceeds forecasts.  ", 'byline': {'original': 'By Bloomberg News'}, 'document_type': 'article', 'headline': {'main': 'World Business Briefing | Asia: Vietnam: Economy Grows 8.4% in 2005', 'kicker': '', 'print_headline': 'World Business Briefing | Asia: Vietnam: Economy Grows 8.4% in 2005'}, '_id': 'nyt://article/2bffae73-2067-539a-932c-ac3eb2d7d672', 'keywords': [], 'multimedia': {'caption': '', 'credit': '', 'default': {'url': '', 'height': 0, 'width': 0}, 'thumbnail': {'url': '', 'height': 0, 'width': 0}}, 'news_desk': 'Business/Financial Desk', 'print_page': '00005', 'print_section': 'C', 'pub_date': '2006-01-04T05:00:00Z', 'section_name': 'Business', 'snippet': "Vietnam's economy expanded last year at the fastest pace in almost a decade, led by gains in construction, tourism and telecommunications. Gross domestic product increased 8.4 percent in 2005, according to preliminary figures released by the General Statistics Office in Hanoi. The figure is up from a 7.8 percent expansion in 2004, and it is the fastest growth since 1996, the statistics office said. Vietnam, which has cut poverty in half since 1993, wants to move out of the ranks of the world's lower-income nations by 2010. The government aims at achieving the target by spurring economic growth to exceed the 7 percent that it averaged in the five years from 2000 to 2004, even as inflation exceeds forecasts.  ", 'source': 'The New York Times', 'subsection_name': '', 'type_of_material': 'News', 'uri': 'nyt://article/2bffae73-2067-539a-932c-ac3eb2d7d672', 'web_url': 'https://www.nytimes.com/2006/01/04/business/world-business-briefing-asia-vietnam-economy-grows-84-in-2005.html', 'word_count': 142}, {'abstract': '', 'byline': {'original': ''}, 'document_type': 'article', 'headline': {'main': "Germany is urged to cut corporate taxes to make economy 'competitive'", 'kicker': '', 'print_headline': "Germany is urged to cut corporate taxes to make economy 'competitive'"}, '_id': 'nyt://article/78511d30-47c7-564c-a59a-ebe62696aec9', 'keyw ...
# Status Code: 200
# Response JSON snippet: {'status': 'OK', 'copyright': 'Copyright (c) 2026 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'abstract': 'Daniel Gross column on yield curve inversion, which has sent stock market into brief tailspin and prompted economic analysts to consider possible implications; departing Federal Reserve chairman Alan Greenspan has labeled persistence of very low long-term interest rates in face of solid growth and rising short-term rates as conundrum; Harvard economics Prof Kenneth Rogoff and others say inverted curve is global and no longer limited to US economy; graphs (M)', 'byline': {'original': 'By Daniel Gross'}, 'document_type': 'article', 'headline': {'main': "The World Isn't Flat, but Its Yield Curve May Be", 'kicker': 'ECONOMIC VIEW', 'print_headline': "ECONOMIC VIEW; The World Isn't Flat, but Its Yield Curve May Be"}, '_id': 'nyt://article/8dbc91c8-5b17-5bf9-8a55-ec15b4ba7425', 'keywords': [{'name': 'Person', 'value': 'Rogoff, Kenneth S', 'rank': 1}, {'name': 'Person', 'value': 'Greenspan, Alan', 'rank': 2}, {'name': 'Subject', 'value': 'United States Economy', 'rank': 3}, {'name': 'Subject', 'value': 'Interest Rates', 'rank': 4}, {'name': 'Subject', 'value': 'Credit', 'rank': 5}, {'name': 'Subject', 'value': 'Stocks and Bonds', 'rank': 6}, {'name': 'Subject', 'value': 'Economic Conditions and Trends', 'rank': 7}], 'multimedia': {'caption': '', 'credit': '', 'default': {'url': '', 'height': 0, 'width': 0}, 'thumbnail': {'url': '', 'height': 0, 'width': 0}}, 'news_desk': 'Money and Business/Financial Desk', 'print_page': '003', 'print_section': '3', 'pub_date': '2006-01-08T05:00:00Z', 'section_name': 'Business', 'snippet': 'Daniel Gross column on yield curve inversion, which has sent stock market into brief tailspin and prompted economic analysts to consider possible implications; departing Federal Reserve chairman Alan Greenspan has labeled persistence of very low long-term interest rates in face of solid growth and rising short-term rates as conundrum; Harvard economics Prof Kenneth Rogoff and others say inverted curve is global and no longer limited to US economy; graphs (M)', 'source': 'The New York Times', 'subsection_name': '', 'type_of_material': 'News', 'uri': 'nyt://article/8dbc91c8-5b17-5bf9-8a55-ec15b4ba7425', 'web_url': 'https://www.nytimes.com/2006/01/08/business/yourmoney/the-world-isnt-flat-but-its-yield-curve-may-be.html', 'word_count': 924}, {'abstract': "Louis Uchitelle Economic View column on quest for full employment, which has rarely been achieved; says there was hint of it in late 1990's, but for Americans under age of 50, experience has been so fleeting that they may not realize that full employment was once hotly pursued goal--condition considered so important that many politicians wanted it legislated and not left to chance; says jobless rate has dipped recently, but remains well above its lows of some previous decades; graph (M)", 'byline': {'original': 'By Louis Uchitelle'}, 'document_type': 'article', 'headline': {'main': 'Chasing Full Employment', 'kicker': 'ECONOMIC VIEW', 'print_headline': 'ECONOMIC VIEW; Chasing Full Employment'}, '_id': 'nyt://article/80356571-5a0e-58e1-b4f9-9696e86125eb', 'keywords': [{'name': 'Subject', 'value': 'LABOR', 'rank': 1}, {'name': 'Subject', 'value': 'United States Economy', 'rank': 2}, {'name': 'Subject', 'value': 'Unemployment', 'rank': 3}], 'multimedia': {'caption': '', 'credit': '', 'default': {'url': '', 'height': 0, 'width': 0}, 'thumbnail': {'url': '', 'height': 0, 'width': 0}}, 'news_desk': 'Money and Business/Financial Desk', 'print_page': '004', 'print_section': '3', 'pub_date': '2006-02-12T05:00:00Z', 'section_name': 'Business', 'snippet': "Louis Uchitelle Economic View column on quest for full employment, which has rarely been achieved; says there was hint of it in late 1990's, but for Americans under age of 50, experience has been so fleeting that they may not realize that full employment was once hotl ...
# Status Code: 429
# Response JSON snippet: {'fault': {'faultstring': 'Rate limit quota violation. Quota limit  exceeded. Identifier : dd126942-a899-454e-b0a0-e37a392517b3', 'detail': {'errorcode': 'policies.ratelimit.QuotaViolation'}}}
# Error or unexpected response
# Status Code: 429
# Response JSON snippet: {'fault': {'faultstring': 'Rate limit quota violation. Quota limit  exceeded. Identifier : dd126942-a899-454e-b0a0-e37a392517b3', 'detail': {'errorcode': 'policies.ratelimit.QuotaViolation'}}}
# Error or unexpected response
# Status Code: 429
# Response JSON snippet: {'fault': {'faultstring': 'Rate limit quota violation. Quota limit  exceeded. Identifier : dd126942-a899-454e-b0a0-e37a392517b3', 'detail': {'errorcode': 'policies.ratelimit.QuotaViolation'}}}
# Error or unexpected response
# Status Code: 429
# Response JSON snippet: {'fault': {'faultstring': 'Rate limit quota violation. Quota limit  exceeded. Identifier : dd126942-a899-454e-b0a0-e37a392517b3', 'detail': {'errorcode': 'policies.ratelimit.QuotaViolation'}}}
# Error or unexpected response
# Status Code: 429
# Response JSON snippet: {'fault': {'faultstring': 'Rate limit quota violation. Quota limit  exceeded. Identifier : dd126942-a899-454e-b0a0-e37a392517b3', 'detail': {'errorcode': 'policies.ratelimit.QuotaViolation'}}}
# Error or unexpected response
#                                             headline              pub_date  \
# 0          Exit Greenspan, Amid Questions on Economy  2006-02-01T05:00:00Z
# 1   Chinese Economy Becomes 4th Largest in the World  2006-01-25T05:00:00Z
# 2  Bush Cites 2 Million New Jobs in 2005 and Heal...  2006-01-07T05:00:00Z
# 3         U.S. Economy Slowed Sharply at End of 2005  2006-01-28T05:00:00Z
# 4  Chinese Economy Grows to 4th Largest in the World  2006-01-25T05:00:00Z
#
#                                              snippet  \
# 0  Alan Greenspan left his successor both a wide ...
# 1  The Chinese statistics, showing a national eco...
# 2  The United States generated about 200,000 new ...
# 3  Economic growth weakened unexpectedly in the f...
# 4  The Chinese statistics, showing a national eco...
#
#                                              web_url
# 0  https://www.nytimes.com/2006/02/01/business/01...
# 1  https://www.nytimes.com/2006/01/25/business/wo...
# 2  https://www.nytimes.com/2006/01/07/politics/bu...
# 3  https://www.nytimes.com/2006/01/28/business/us...
# 4  https://www.nytimes.com/2006/01/25/business/wo...

# %%
all_articles.shape
# Out:
# (50, 4)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

def get_sentiment(text):
    return analyzer.polarity_scores(text)["compound"]

all_articles["sentiment"] = all_articles["snippet"].apply(get_sentiment)

# %%
all_articles["pub_date"] = pd.to_datetime(all_articles["pub_date"])
all_articles["day"] = all_articles["pub_date"].dt.date

daily_sentiment = (
    all_articles
    .groupby("day")["sentiment"]
    .mean()
    .reset_index()
)

daily_sentiment.head()
# Out:
#           day  sentiment
# 0  2006-01-01   0.680800
# 1  2006-01-03   0.025800
# 2  2006-01-04   0.025800
# 3  2006-01-06  -0.113733
# 4  2006-01-07   0.229400

# %%
daily_sentiment.shape
# Out:
# (27, 2)

# %%
all_articles.shape
# Out:
# (50, 6)
